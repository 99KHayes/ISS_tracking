# %% [markdown]
# # ISS Tracking
#
# ## Track the position of the ISS over the earth.

# %%
# Import all packages needed

import geopandas 
import numpy as np
import pandas as pd
from shapely.geometry import Point
import seaborn as sns
import matplotlib.pyplot as plt
import requests
import time
# %matplotlib inline

# %% [markdown]
# ## ISS info
#
# Use requests to fetch the ISS positional data from the ISS API. Manipulate the data to create Point objects of the coordinates as a column.

# %%
# Create a loop to get the ISS info over x seconds every 10 seconds

ISS_loc = []
count = 0
while count <= 1200:    
    # Reachout to the ISS API
    response = requests.get("http://api.open-notify.org/iss-now.json")
    status = response.status_code
    
    # Check status code for an appropriate response fromt the API
    if status != 200:
        print(f'Error improper response code. Code is {status}')
        break
    else:
        # Turn the API response into JSON
        resp = response.json()
        # append each API response to the list of ISS locations
        ISS_loc.append(resp)
        # pause the loop for 10 seconds to allow the ISS to move slightly
        time.sleep(10)
        # Add to the count so it doesn't access the API too many times
        count = count + 1

# %%
# Check the data from the API
ISS_loc[:5]
# Out:
# [{'iss_position': {'longitude': '115.3192', 'latitude': '18.4946'},
#   'timestamp': 1563193841,
#   'message': 'success'},
#  {'iss_position': {'longitude': '115.7460', 'latitude': '19.0085'},
#   'timestamp': 1563193851,
#   'message': 'success'},
#  {'iss_position': {'longitude': '116.1551', 'latitude': '19.4969'},
#   'timestamp': 1563193861,
#   'message': 'success'},
#  {'iss_position': {'longitude': '116.5671', 'latitude': '19.9842'},
#   'timestamp': 1563193871,
#   'message': 'success'},
#  {'iss_position': {'longitude': '116.9818', 'latitude': '20.4703'},
#   'timestamp': 1563193881,
#   'message': 'success'}]

# %%
# Initialize empy dictionary ( will becoem the ISS dataframe)
ISS_dict={'latitude': None, 'longitude': None, 'timestamp': None}
# Initialize empty lists to populate with values from the API
lat_list = []
long_list = []
time_list = []

# Loop through the API list and extract latitude, longitude, and timestamp
for i in range(0,len(ISS_loc)):
    lat_list.append(ISS_loc[i]['iss_position']['latitude'])
    long_list.append(ISS_loc[i]['iss_position']['longitude'])
    time_list.append(ISS_loc[i]['timestamp'])

# Populate ISS dictionary
ISS_dict['latitude'] = lat_list
ISS_dict['longitude'] = long_list
ISS_dict['timestamp'] = time_list

# Turn the ISS position dictionary into a data frame 
ISS_df = pd.DataFrame.from_dict(ISS_dict)

# %%
# Inspect ISS dataframe 
ISS_df.head()
# Out:
#   latitude longitude   timestamp
# 0  18.4946  115.3192  1563193841
# 1  19.0085  115.7460  1563193851
# 2  19.4969  116.1551  1563193861
# 3  19.9842  116.5671  1563193871
# 4  20.4703  116.9818  1563193881

# %%
# Change values to integers from strings
ISS_df['latitude'] = ISS_df['latitude'].astype(float)
ISS_df['longitude'] = ISS_df['longitude'].astype(float)
ISS_df['timestamp'] = ISS_df['timestamp'].astype(float)

# %%
# Make a coordinates column that has a value of a list of longitude and latitude
ISS_df['coordinates'] = ISS_df[['longitude', 'latitude']].values.tolist()

# %%
# Make the coordinate column a Point object
ISS_df['coordinates'] = ISS_df['coordinates'].apply(Point)

# %%
# Inspect the ISS_df
ISS_df.head()
# Out:
#    latitude  longitude     timestamp               coordinates
# 0   18.4946   115.3192  1.563194e+09  POINT (115.3192 18.4946)
# 1   19.0085   115.7460  1.563194e+09   POINT (115.746 19.0085)
# 2   19.4969   116.1551  1.563194e+09  POINT (116.1551 19.4969)
# 3   19.9842   116.5671  1.563194e+09  POINT (116.5671 19.9842)
# 4   20.4703   116.9818  1.563194e+09  POINT (116.9818 20.4703)

# %%
# Convert pandas datframe into a geopandas dataframe
geo_ISS = geopandas.GeoDataFrame(ISS_df, geometry='coordinates', crs={'init': 'epsg:4326'})
print(type(geo_ISS))
geo_ISS.head()
# Out:
# <class 'geopandas.geodataframe.GeoDataFrame'>
#    latitude  longitude     timestamp               coordinates
# 0   18.4946   115.3192  1.563194e+09  POINT (115.3192 18.4946)
# 1   19.0085   115.7460  1.563194e+09   POINT (115.746 19.0085)
# 2   19.4969   116.1551  1.563194e+09  POINT (116.1551 19.4969)
# 3   19.9842   116.5671  1.563194e+09  POINT (116.5671 19.9842)
# 4   20.4703   116.9818  1.563194e+09  POINT (116.9818 20.4703)

# %%
# Save dataframe into CSV so the loop does not have to be run everytime
geo_ISS.to_csv('ISS_df.csv')

# %% [markdown]
# ## Earth info
#
# Used this [custom GEOJSON Creator](https://geojson-maps.ash.ms/) to create a GEOJSON file. Read the file in as a Geopandas dataframe and inspected it.

# %%
# Read in the geojson file and inspect it
earth = geopandas.read_file("custom.geo.json")
earth.head()
# Out:
#    scalerank       featurecla  labelrank           sovereignt sov_a3  \
# 0          3  Admin-0 country          5          Netherlands    NL1
# 1          1  Admin-0 country          4          The Bahamas    BHS
# 2          1  Admin-0 country          5             Barbados    BRB
# 3          1  Admin-0 country          6  Antigua and Barbuda    ATG
# 4          3  Admin-0 country          6       United Kingdom    GB1
#
#    adm0_dif  level               type                admin adm0_a3  ...  \
# 0         1      2            Country                Aruba     ABW  ...
# 1         0      2  Sovereign country          The Bahamas     BHS  ...
# 2         0      2  Sovereign country             Barbados     BRB  ...
# 3         0      2  Sovereign country  Antigua and Barbuda     ATG  ...
# 4         1      2         Dependency              Bermuda     BMU  ...
#
#    region_un         subregion                  region_wb  name_len long_len  \
# 0   Americas         Caribbean  Latin America & Caribbean         5        5
# 1   Americas         Caribbean  Latin America & Caribbean         7        7
# 2   Americas         Caribbean  Latin America & Caribbean         8        8
# 3   Americas         Caribbean  Latin America & Caribbean        17       19
# 4   Americas  Northern America              North America         7        7
#
#   abbrev_len  tiny homepart     filename  \
# 0          5     4      -99  ABW.geojson
# 1          4   -99        1  BHS.geojson
# 2          5     3        1  BRB.geojson
# 3          6     4        1  ATG.geojson
# 4          5     4      -99  BMU.geojson
#
#                                             geometry
# 0  POLYGON ((-69.89912109375 12.45200195312499, -...
# 1  (POLYGON ((-73.02685546874994 21.1923828125000...
# 2  POLYGON ((-59.49331054687499 13.081982421875, ...
# 3  (POLYGON ((-61.71606445312502 17.0370117187499...
# 4  POLYGON ((-64.73027343749999 32.29345703125, -...
#
# [5 rows x 65 columns]

# %%
# Further inspection of the earth geodataframe
earth.describe
# Out:
# <bound method NDFrame.describe of      scalerank       featurecla  labelrank                      sovereignt  \
# 0            3  Admin-0 country          5                     Netherlands
# 1            1  Admin-0 country          4                     The Bahamas
# 2            1  Admin-0 country          5                        Barbados
# 3            1  Admin-0 country          6             Antigua and Barbuda
# 4            3  Admin-0 country          6                  United Kingdom
# 5            1  Admin-0 country          5                      Costa Rica
# 6            1  Admin-0 country          2                          Canada
# 7            1  Admin-0 country          6                  United Kingdom
# 8            1  Admin-0 country          6                          Belize
# 9            1  Admin-0 country          3                            Cuba
# 10           3  Admin-0 country          6                          France
# 11           1  Admin-0 country          3                       Guatemala
# 12           1  Admin-0 country          3                         Denmark
# 13           1  Admin-0 country          6                        Dominica
# 14           1  Admin-0 country          5              Dominican Republic
# 15           1  Admin-0 country          5                  United Kingdom
# 16           3  Admin-0 country          5                     Netherlands
# 17           1  Admin-0 country          5                        Honduras
# 18           1  Admin-0 country          6                         Grenada
# 19           1  Admin-0 country          6                     Saint Lucia
# 20           1  Admin-0 country          5                           Haiti
# 21           1  Admin-0 country          6           Saint Kitts and Nevis
# 22           1  Admin-0 country          4                         Jamaica
# 23           3  Admin-0 country          6                          France
# 24           1  Admin-0 country          2                          Mexico
# 25           1  Admin-0 country          4                          Panama
# 26           1  Admin-0 country          5                       Nicaragua
# 27           3  Admin-0 country          6                  United Kingdom
# 28           1  Admin-0 country          2        United States of America
# 29           1  Admin-0 country          5        United States of America
# ..         ...              ...        ...                             ...
# 202          1  Admin-0 country          2                          Russia
# 203          1  Admin-0 country          6                        Slovenia
# 204          3  Admin-0 country          6                      San Marino
# 205          1  Admin-0 country          6                        Slovakia
# 206          1  Admin-0 country          3                         Ukraine
# 207          5  Admin-0 country          5                       Australia
# 208          3  Admin-0 country          6        United States of America
# 209          6  Admin-0 country          6                         Vatican
# 210          3  Admin-0 country          4                     New Zealand
# 211          1  Admin-0 country          6                        Kiribati
# 212          1  Admin-0 country          6                            Fiji
# 213          3  Admin-0 country          4        United States of America
# 214          3  Admin-0 country          6  Federated States of Micronesia
# 215          5  Admin-0 country          5                       Australia
# 216          1  Admin-0 country          2                       Australia
# 217          1  Admin-0 country          3                          France
# 218          3  Admin-0 country          6                           Nauru
# 219          3  Admin-0 country          4                     New Zealand
# 220          3  Admin-0 country          6        United States of America
# 221          1  Admin-0 country          6                           Palau
# 222          1  Admin-0 country          2                     New Zealand
# 223          3  Admin-0 country          4                  United Kingdom
# 224          1  Admin-0 country          2                Papua New Guinea
# 225          3  Admin-0 country          4                          France
# 226          1  Admin-0 country          3                 Solomon Islands
# 227          3  Admin-0 country          4                          France
# 228          3  Admin-0 country          4                           Tonga
# 229          1  Admin-0 country          4                         Vanuatu
# 230          1  Admin-0 country          4                           Samoa
# 231          5  Admin-0 country          6                Marshall Islands
#
#     sov_a3  adm0_dif  level               type  \
# 0      NL1         1      2            Country
# 1      BHS         0      2  Sovereign country
# 2      BRB         0      2  Sovereign country
# 3      ATG         0      2  Sovereign country
# 4      GB1         1      2         Dependency
# 5      CRI         0      2  Sovereign country
# 6      CAN         0      2  Sovereign country
# 7      GB1         1      2         Dependency
# 8      BLZ         0      2  Sovereign country
# 9      CUB         0      2  Sovereign country
# 10     FR1         1      2         Dependency
# 11     GTM         0      2  Sovereign country
# 12     DN1         1      2            Country
# 13     DMA         0      2  Sovereign country
# 14     DOM         0      2  Sovereign country
# 15     GB1         1      2         Dependency
# 16     NL1         1      2            Country
# 17     HND         0      2  Sovereign country
# 18     GRD         0      2  Sovereign country
# 19     LCA         0      2  Sovereign country
# 20     HTI         0      2  Sovereign country
# 21     KNA         0      2  Sovereign country
# 22     JAM         0      2  Sovereign country
# 23     FR1         1      2         Dependency
# 24     MEX         0      2  Sovereign country
# 25     PAN         0      2  Sovereign country
# 26     NIC         0      2  Sovereign country
# 27     GB1         1      2         Dependency
# 28     US1         1      2            Country
# 29     US1         1      2         Dependency
# ..     ...       ...    ...                ...
# 202    RUS         0      2  Sovereign country
# 203    SVN         0      2  Sovereign country
# 204    SMR         0      2  Sovereign country
# 205    SVK         0      2  Sovereign country
# 206    UKR         0      2  Sovereign country
# 207    AU1         1      2         Dependency
# 208    US1         1      2         Dependency
# 209    VAT         0      2  Sovereign country
# 210    NZ1         1      2         Dependency
# 211    KIR         0      2  Sovereign country
# 212    FJI         0      2  Sovereign country
# 213    US1         1      2         Dependency
# 214    FSM         0      2  Sovereign country
# 215    AU1         1      2         Dependency
# 216    AU1         1      2            Country
# 217    FR1         1      2         Dependency
# 218    NRU         0      2  Sovereign country
# 219    NZ1         1      2         Dependency
# 220    US1         1      2         Dependency
# 221    PLW         0      2  Sovereign country
# 222    NZ1         1      2            Country
# 223    GB1         1      2         Dependency
# 224    PNG         0      2  Sovereign country
# 225    FR1         1      2         Dependency
# 226    SLB         0      2  Sovereign country
# 227    FR1         1      2         Dependency
# 228    TON         0      2  Sovereign country
# 229    VUT         0      2  Sovereign country
# 230    WSM         0      2  Sovereign country
# 231    MHL         0      2  Sovereign country
#
#                               admin adm0_a3  ...  region_un  \
# 0                             Aruba     ABW  ...   Americas
# 1                       The Bahamas     BHS  ...   Americas
# 2                          Barbados     BRB  ...   Americas
# 3               Antigua and Barbuda     ATG  ...   Americas
# 4                           Bermuda     BMU  ...   Americas
# 5                        Costa Rica     CRI  ...   Americas
# 6                            Canada     CAN  ...   Americas
# 7                          Anguilla     AIA  ...   Americas
# 8                            Belize     BLZ  ...   Americas
# 9                              Cuba     CUB  ...   Americas
# 10                 Saint Barthelemy     BLM  ...   Americas
# 11                        Guatemala     GTM  ...   Americas
# 12                        Greenland     GRL  ...   Americas
# 13                         Dominica     DMA  ...   Americas
# 14               Dominican Republic     DOM  ...   Americas
# 15                   Cayman Islands     CYM  ...   Americas
# 16                          Curaçao     CUW  ...   Americas
# 17                         Honduras     HND  ...   Americas
# 18                          Grenada     GRD  ...   Americas
# 19                      Saint Lucia     LCA  ...   Americas
# 20                            Haiti     HTI  ...   Americas
# 21            Saint Kitts and Nevis     KNA  ...   Americas
# 22                          Jamaica     JAM  ...   Americas
# 23                     Saint Martin     MAF  ...   Americas
# 24                           Mexico     MEX  ...   Americas
# 25                           Panama     PAN  ...   Americas
# 26                        Nicaragua     NIC  ...   Americas
# 27                       Montserrat     MSR  ...   Americas
# 28         United States of America     USA  ...   Americas
# 29                      Puerto Rico     PRI  ...   Americas
# ..                              ...     ...  ...        ...
# 202                          Russia     RUS  ...     Europe
# 203                        Slovenia     SVN  ...     Europe
# 204                      San Marino     SMR  ...     Europe
# 205                        Slovakia     SVK  ...     Europe
# 206                         Ukraine     UKR  ...     Europe
# 207     Ashmore and Cartier Islands     ATC  ...    Oceania
# 208                            Guam     GUM  ...    Oceania
# 209                         Vatican     VAT  ...     Europe
# 210                    Cook Islands     COK  ...    Oceania
# 211                        Kiribati     KIR  ...    Oceania
# 212                            Fiji     FJI  ...    Oceania
# 213                  American Samoa     ASM  ...    Oceania
# 214  Federated States of Micronesia     FSM  ...    Oceania
# 215                  Norfolk Island     NFK  ...    Oceania
# 216                       Australia     AUS  ...    Oceania
# 217                   New Caledonia     NCL  ...    Oceania
# 218                           Nauru     NRU  ...    Oceania
# 219                            Niue     NIU  ...    Oceania
# 220        Northern Mariana Islands     MNP  ...    Oceania
# 221                           Palau     PLW  ...    Oceania
# 222                     New Zealand     NZL  ...    Oceania
# 223                Pitcairn Islands     PCN  ...    Oceania
# 224                Papua New Guinea     PNG  ...    Oceania
# 225               Wallis and Futuna     WLF  ...    Oceania
# 226                 Solomon Islands     SLB  ...    Oceania
# 227                French Polynesia     PYF  ...    Oceania
# 228                           Tonga     TON  ...    Oceania
# 229                         Vanuatu     VUT  ...    Oceania
# 230                           Samoa     WSM  ...    Oceania
# 231                Marshall Islands     MHL  ...    Oceania
#
#                      subregion                  region_wb  name_len long_len  \
# 0                    Caribbean  Latin America & Caribbean         5        5
# 1                    Caribbean  Latin America & Caribbean         7        7
# 2                    Caribbean  Latin America & Caribbean         8        8
# 3                    Caribbean  Latin America & Caribbean        17       19
# 4             Northern America              North America         7        7
# 5              Central America  Latin America & Caribbean        10       10
# 6             Northern America              North America         6        6
# 7                    Caribbean  Latin America & Caribbean         8        8
# 8              Central America  Latin America & Caribbean         6        6
# 9                    Caribbean  Latin America & Caribbean         4        4
# 10                   Caribbean  Latin America & Caribbean        13       16
# 11             Central America  Latin America & Caribbean         9        9
# 12            Northern America      Europe & Central Asia         9        9
# 13                   Caribbean  Latin America & Caribbean         8        8
# 14                   Caribbean  Latin America & Caribbean        14       18
# 15                   Caribbean  Latin America & Caribbean        10       14
# 16                   Caribbean  Latin America & Caribbean         7        7
# 17             Central America  Latin America & Caribbean         8        8
# 18                   Caribbean  Latin America & Caribbean         7        7
# 19                   Caribbean  Latin America & Caribbean        11       11
# 20                   Caribbean  Latin America & Caribbean         5        5
# 21                   Caribbean  Latin America & Caribbean        19       21
# 22                   Caribbean  Latin America & Caribbean         7        7
# 23                   Caribbean  Latin America & Caribbean         9       12
# 24             Central America  Latin America & Caribbean         6        6
# 25             Central America  Latin America & Caribbean         6        6
# 26             Central America  Latin America & Caribbean         9        9
# 27                   Caribbean  Latin America & Caribbean        10       10
# 28            Northern America              North America        13       13
# 29                   Caribbean  Latin America & Caribbean        11       11
# ..                         ...                        ...       ...      ...
# 202             Eastern Europe      Europe & Central Asia         6       18
# 203            Southern Europe      Europe & Central Asia         8        8
# 204            Southern Europe      Europe & Central Asia        10       10
# 205             Eastern Europe      Europe & Central Asia         8        8
# 206             Eastern Europe      Europe & Central Asia         7        7
# 207  Australia and New Zealand        East Asia & Pacific        23       27
# 208                 Micronesia        East Asia & Pacific         4        4
# 209            Southern Europe      Europe & Central Asia         7        7
# 210                  Polynesia        East Asia & Pacific         8       12
# 211                 Micronesia        East Asia & Pacific         8        8
# 212                  Melanesia        East Asia & Pacific         4        4
# 213                  Polynesia        East Asia & Pacific        14       14
# 214                 Micronesia        East Asia & Pacific        10       30
# 215  Australia and New Zealand        East Asia & Pacific        14       14
# 216  Australia and New Zealand        East Asia & Pacific         9        9
# 217                  Melanesia        East Asia & Pacific        13       13
# 218                 Micronesia        East Asia & Pacific         5        5
# 219                  Polynesia        East Asia & Pacific         4        4
# 220                 Micronesia        East Asia & Pacific        14       24
# 221                 Micronesia        East Asia & Pacific         5        5
# 222  Australia and New Zealand        East Asia & Pacific        11       11
# 223                  Polynesia        East Asia & Pacific        12       16
# 224                  Melanesia        East Asia & Pacific        16       16
# 225                  Polynesia        East Asia & Pacific        21       25
# 226                  Melanesia        East Asia & Pacific        11       15
# 227                  Polynesia        East Asia & Pacific        13       16
# 228                  Polynesia        East Asia & Pacific         5        5
# 229                  Melanesia        East Asia & Pacific         7        7
# 230                  Polynesia        East Asia & Pacific         5        5
# 231                 Micronesia        East Asia & Pacific        12       16
#
#     abbrev_len  tiny homepart                     filename  \
# 0            5     4      -99                  ABW.geojson
# 1            4   -99        1                  BHS.geojson
# 2            5     3        1                  BRB.geojson
# 3            6     4        1                  ATG.geojson
# 4            5     4      -99                  BMU.geojson
# 5            4   -99        1                  CRI.geojson
# 6            4   -99        1                  CAN.geojson
# 7            4   -99      -99                  AIA.geojson
# 8            6   -99        1                  BLZ.geojson
# 9            4   -99        1                  CUB.geojson
# 10           6     4      -99                  BLM.geojson
# 11           5     4        1                  GTM.geojson
# 12           6   -99      -99                  GRL.geojson
# 13           6     4        1                  DMA.geojson
# 14           9   -99        1                  DOM.geojson
# 15           8     2      -99                  CYM.geojson
# 16           4     4      -99                  CUW.geojson
# 17           5   -99        1                  HND.geojson
# 18           5   -99        1                  GRD.geojson
# 19           4     4        1                  LCA.geojson
# 20           5   -99        1                  HTI.geojson
# 21           7     4        1                  KNA.geojson
# 22           4   -99        1                  JAM.geojson
# 23           6     4      -99                  MAF.geojson
# 24           4   -99        1                  MEX.geojson
# 25           4   -99        1                  PAN.geojson
# 26           4   -99        1                  NIC.geojson
# 27           6     6      -99                  MSR.geojson
# 28           6   -99        1                  USA.geojson
# 29           4   -99      -99                  PRI.geojson
# ..         ...   ...      ...                          ...
# 202          4   -99        1                  RUS.geojson
# 203          4   -99        1                  SVN.geojson
# 204          4     5        1                  SMR.geojson
# 205          4   -99        1                  SVK.geojson
# 206          4   -99        1                  UKR.geojson
# 207          7   -99      -99  ashmoreandcartieris.geojson
# 208          4     2      -99                  GUM.geojson
# 209          4     4        1                  VAT.geojson
# 210          8     3      -99                  COK.geojson
# 211          4     2        1                  KIR.geojson
# 212          4   -99        1                  FJI.geojson
# 213          9     3      -99                  ASM.geojson
# 214          6   -99        1                  FSM.geojson
# 215          7   -99      -99                  NFK.geojson
# 216          4   -99        1                  AUS.geojson
# 217          6   -99      -99                  NCL.geojson
# 218          5     3        1                  NRU.geojson
# 219          4     3      -99                  NIU.geojson
# 220          6     3      -99                  MNP.geojson
# 221          5     2        1                  PLW.geojson
# 222          4   -99        1                  NZL.geojson
# 223          8   -99      -99                  PCN.geojson
# 224          6   -99        1                  PNG.geojson
# 225          4     3      -99                  WLF.geojson
# 226          6   -99        1                  SLB.geojson
# 227          9     2      -99                  PYF.geojson
# 228          5     3        1                  TON.geojson
# 229          4     2        1                  VUT.geojson
# 230          5   -99        1                  WSM.geojson
# 231          6     2        1                  MHL.geojson
#
#                                               geometry
# 0    POLYGON ((-69.89912109375 12.45200195312499, -...
# 1    (POLYGON ((-73.02685546874994 21.1923828125000...
# 2    POLYGON ((-59.49331054687499 13.081982421875, ...
# 3    (POLYGON ((-61.71606445312502 17.0370117187499...
# 4    POLYGON ((-64.73027343749999 32.29345703125, -...
# 5    POLYGON ((-83.64199218749999 10.917236328125, ...
# 6    (POLYGON ((-59.78759765624998 43.9395996093749...
# 7    POLYGON ((-63.00122070312499 18.22177734374999...
# 8    (POLYGON ((-87.85292968749998 17.4228515625, -...
# 9    (POLYGON ((-82.56176757812503 21.5716796875000...
# 10   POLYGON ((-62.83193359375 17.87646484375, -62....
# 11   POLYGON ((-89.16147460937498 17.81484375, -89....
# 12   (POLYGON ((-46.26669921875001 60.7813964843749...
# 13   POLYGON ((-61.281689453125 15.2490234375, -61....
# 14   POLYGON ((-71.768310546875 18.03916015624999, ...
# 15   (POLYGON ((-81.36953124999997 19.3488769531249...
# 16   POLYGON ((-68.75107421874999 12.059765625, -68...
# 17   (POLYGON ((-85.78398437500002 16.0028320312499...
# 18   POLYGON ((-61.71552734375 12.012646484375, -61...
# 19   POLYGON ((-60.89521484375 13.82197265625, -60....
# 20   (POLYGON ((-72.80458984374997 18.7776855468750...
# 21   (POLYGON ((-62.53222656250002 17.121875, -62.5...
# 22   POLYGON ((-77.261474609375 18.45742187499999, ...
# 23   POLYGON ((-63.01118164062499 18.06894531249999...
# 24   (POLYGON ((-91.68369140624998 18.6773437500000...
# 25   (POLYGON ((-81.60327148437497 7.33281249999998...
# 26   POLYGON ((-83.15751953124999 14.99306640625, -...
# 27   POLYGON ((-62.1484375 16.74033203124999, -62.1...
# 28   (POLYGON ((-155.58134765625 19.01201171875002,...
# 29   (POLYGON ((-67.87246093749997 18.0598632812500...
# ..                                                 ...
# 202  (POLYGON ((146.0456054687501 43.40932617187497...
# 203  POLYGON ((16.51621093750001 46.49990234374999,...
# 204  POLYGON ((12.48525390625002 43.90141601562499,...
# 205  POLYGON ((22.538671875 49.07270507812499, 22.5...
# 206  (POLYGON ((32.01220703124997 46.20390624999998...
# 207  POLYGON ((123.59453125 -12.42568359375001, 123...
# 208  POLYGON ((144.741796875 13.25927734375, 144.69...
# 209  POLYGON ((12.43916015625001 41.89838867187499,...
# 210  POLYGON ((-159.74052734375 -21.24921875000001,...
# 211  (POLYGON ((-151.7826171875 -11.44101562499999,...
# 212  (POLYGON ((174.6296875 -21.69501953125001, 174...
# 213  POLYGON ((-170.72626953125 -14.351171875, -170...
# 214  (POLYGON ((162.9832031250001 5.325732421875003...
# 215  POLYGON ((167.939453125 -29.01767578125, 167.9...
# 216  (POLYGON ((158.8788085937501 -54.7097656249999...
# 217  (POLYGON ((167.54443359375 -22.62324218750001,...
# 218  POLYGON ((166.9583984375 -0.5166015625, 166.93...
# 219  POLYGON ((-169.80341796875 -19.0830078125, -16...
# 220  (POLYGON ((145.26484375 14.15810546875004, 145...
# 221  (POLYGON ((131.17236328125 3.026220703125048, ...
# 222  (POLYGON ((169.17822265625 -52.497265625, 169....
# 223  POLYGON ((-128.290087890625 -24.39736328125001...
# 224  (POLYGON ((153.5361328125 -11.47617187499995, ...
# 225  (POLYGON ((-178.0466796875 -14.31835937499998,...
# 226  (POLYGON ((166.92919921875 -11.66513671874999,...
# 227  (POLYGON ((-138.5058593749999 -20.857226562500...
# 228  (POLYGON ((-174.913134765625 -21.3004882812500...
# 229  (POLYGON ((169.8962890625001 -20.1866210937500...
# 230  (POLYGON ((-171.4541015625 -14.04648437500002,...
# 231  (POLYGON ((169.6350585937501 5.830078124999986...
#
# [232 rows x 65 columns]>

# %%
# Further inspection of the earth geodataframe
earth.shape
# Out:
# (232, 65)

# %%
# View the plot of the geojson Polygon objects
earth.plot(figsize=(15,10),  color='#0B2380',)

# %%
#Plot the ISS Path
geo_ISS.plot(figsize=(15,10), color='blue')

# %%
# Plotting to see the ISS overlay the world:
# make earth the base figure
fig, ax = plt.subplots(1, figsize=(30,20))
base = earth.plot(ax=ax, color='#8BE898',)
base.set_facecolor('#9CD6FF')

# plotting the ISS position over the eart with navy
geo_ISS.plot(ax=base, marker="*", markersize=10, cmap = 'jet');
fig.savefig('ISS path')
